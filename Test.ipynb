# %%
import cv2
import torch
 
 ## Ejemplo para utilizar cuda

# %%
# Out:
# array([[0.41783574, 0.41101366, 0.4041916 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.41347763, 0.41126037, 0.4090431 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.40911952, 0.411507  , 0.4138946 , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [5.560469  , 5.562216  , 5.563963  , ..., 9.788919  , 9.7794075 ,
#         9.769895  ],
#        [5.5357447 , 5.5461793 , 5.556614  , ..., 9.802221  , 9.783747  ,
#         9.765273  ],
#        [5.5110207 , 5.530143  , 5.5492654 , ..., 9.815523  , 9.788088  ,
#         9.760653  ]], dtype=float32)
